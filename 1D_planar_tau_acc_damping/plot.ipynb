# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

p = np.loadtxt("p.csv", dtype=float)
Dz_i = np.loadtxt("Dz_i.csv", dtype=float)
Dz_f = np.loadtxt("Dz_f.csv", dtype=float)
f0_1 = np.loadtxt("f0_1.csv", dtype=float)
f0_2 = np.loadtxt("f0_2.csv", dtype=float)
f_1 = np.loadtxt("f_1.csv", dtype=float)
f_2 = np.loadtxt("f_2.csv", dtype=float)

# plot 1

fig, ax = plt.subplots()

ax.plot(p*3e10/1.6e-3, np.power(p,4)*f0_1, ls='-', c="black", label="1st order (z=0)")
ax.plot(p*3e10/1.6e-3, np.power(p,4)*f_1, ls='--', c="black", label="1st order (z=z0/2)")

ax.plot(p*3e10/1.6e-3, np.power(p,4)*f0_2, ls='-', c="red", label="1st order & 2nd order (z=0)")
ax.plot(p*3e10/1.6e-3, np.power(p,4)*f_2, ls='--', c="red", label="1st order & 2nd order (z=z0/2)")

ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(1e0,1e7)
ax.set_ylim(2e-24,1e-23)
ax.set_xlabel("p (GeV/c)")
ax.set_ylabel(r"$\rm p^{4} \, f(p)$")
ax.set_title("No damping")
ax.legend(loc="lower left")
plt.tight_layout()
plt.savefig("f.png", dpi=500)
plt.show()

# plot 2

fig, ax = plt.subplots()

ax.plot(p*3e10/1.6e-3, Dz_i, ls="-", c="black", label=r"$D_{zz}(p)\propto p^{1/3}$")
ax.plot(p*3e10/1.6e-3, Dz_f, ls="--", c="red", label="after 1st update")

ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(1e0,1e7)
ax.set_ylim(1e25,1e35)
ax.set_xlabel("p (GeV/c)")
ax.set_ylabel(r"$\rm D_{zz}(p)$")
ax.legend()
plt.tight_layout()
plt.savefig("D.png", dpi=500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import numpy as np
#       3 import csv
# ----> 5 p = np.loadtxt("p.csv", dtype=float)
#       6 Dz_i = np.loadtxt("Dz_i.csv", dtype=float)
#       7 Dz_f = np.loadtxt("Dz_f.csv", dtype=float)
#
# File c:\Users\14525\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
# ...
